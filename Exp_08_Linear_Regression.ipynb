# %% [markdown]
# <a href="https://colab.research.google.com/github/krish73055/ITA0602-Machine-Learning/blob/main/Exp_08_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([2, 4, 6, 8, 10, 12])

model = LinearRegression()

model.fit(X, y)

y_pred = model.predict(X)

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)

print("Predicted Values:")
print(y_pred)

print("Mean Squared Error:",
      mean_squared_error(y, y_pred))

print("R2 Score:",
      r2_score(y, y_pred))

print("Prediction for X = 7:",
      model.predict([[7]])[0])
# Out:
# Coefficient: 1.9999999999999996
# Intercept: 1.7763568394002505e-15
# Predicted Values:
# [ 2.  4.  6.  8. 10. 12.]
# Mean Squared Error: 9.532069271420559e-31
# R2 Score: 1.0
# Prediction for X = 7: 13.999999999999998
